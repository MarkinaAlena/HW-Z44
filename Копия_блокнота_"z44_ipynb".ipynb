# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkinaAlena/HW-Z44/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22z44_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.DataFrame({'whoAmI':lst})

# %%
one_hot = pd.get_dummies(data['whoAmI'].map({'robot': 1, 'human': 0}))

# %%
data = data.join(one_hot)

# %%
data.head()
# Out:
#   whoAmI  human  robot
# 0  robot      0      1
# 1  robot      0      1
# 2  robot      0      1
# 3  robot      0      1
# 4  robot      0      1
